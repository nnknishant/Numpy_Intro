# %%
import numpy as np

# %%
# create an array
a = [1,2,3,4,5]
a_array = np.array(a)
a_array
# Out:
# array([1, 2, 3, 4, 5])

# %%
# Again create another array
b = ("mango", "papaya", "litchi", "apple")
array_b = np.array(b)
array_b
# Out:
# array(['mango', 'papaya', 'litchi', 'apple'], dtype='<U6')

# %%
# Again create another array
b = (200.23,20.25,15.00,45.05)
array_b = np.array(b)
array_b
# Out:
# array([200.23,  20.25,  15.  ,  45.05])

# %%
array_b.dtype # check the data types
# Out:
# dtype('float64')

# %%
# check the dimension 
array_b.ndim
# Out:
# 1

# %%
a = [[2,3,4], [3,4,5]]
array_a1 = np.array(a)
array_a1.ndim
# Out:
# 2

# %%
a = [[2,3,4], [3,4,5]]
array_a1 = np.array(a)
array_a1.dtype
# Out:
# dtype('int32')

# %%
array_a1
# Out:
# array([[2, 3, 4],
#        [3, 4, 5]])

# %%
# check the shape
array_a1.shape
# Out:
# (2, 3)

# %%
array_b.size
# Out:
# 4

# %%
# access elements in array
array_a1[0,1]
# Out:
# np.int32(3)

# %%
array_a1[1,2]
# Out:
# np.int32(5)

# %%
#check  the array again

a = [[1,2,3,4],[2,3,4,5],[4,5,6,7]]
array_b1 = np.array(a)

# %%
array_b1
# Out:
# array([[1, 2, 3, 4],
#        [2, 3, 4, 5],
#        [4, 5, 6, 7]])

# %%
#check the elements in arrays
array_b1[2,2]
# Out:
# np.int32(6)

# %%
array_b1.ndim
# Out:
# 2

# %%
#check the negative elements in array[r,c]

array_b1[0,-2]
# Out:
# np.int32(3)

# %%
#check the negative elements in array[r,c]

array_b1[1,-2]
# Out:
# np.int32(4)

# %%
# we use also slicing  here in arrays
array_b1[1,:]
# Out:
# array([2, 3, 4, 5])

# %%
array_b1
# Out:
# array([[1, 2, 3, 4],
#        [2, 3, 4, 5],
#        [4, 5, 6, 7]])

# %%
array_b1[2,:]
# Out:
# array([4, 5, 6, 7])

# %%
# Assign the values / change the values

array_b1[2,2]= 21

# %%
array_b1 # Now the values has changed.
# Out:
# array([[ 1,  2,  3,  4],
#        [ 2,  3,  4,  5],
#        [ 4,  5, 21,  7]])

# %%
# Now 3D arrays
c = [[[1,2],[2,6]],[[2,3],[2,6]]]
array_c1 = np.array(c)
array_c1.shape
# Out:
# (2, 2, 2)

# %%
c = [[[1,2],[2,6]],[[2,3],[2,6]]]
array_c1 = np.array(c)
array_c1
# Out:
# array([[[1, 2],
#         [2, 6]],
#
#        [[2, 3],
#         [2, 6]]])

# %%
array_c1.ndim
# Out:
# 3

# %%
# so now check the elements in arrays 
array_c1[0,0,0]
# Out:
# np.int32(1)

# %%
# so now check the elements in arrays 
array_c1[1,1,0]
# Out:
# np.int32(2)
